# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', 200)

# %%
df = pd.read_feather("train_data.ftr")
print(df.shape)
df.head()
# Out:
# (5531451, 191)
#                                          customer_ID        S_2       P_2  \
# 0  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f... 2017-03-09  0.938477
# 1  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f... 2017-04-07  0.936523
# 2  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f... 2017-05-28  0.954102
# 3  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f... 2017-06-13  0.960449
# 4  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f... 2017-07-16  0.947266
#
#        D_39       B_1       B_2       R_1       S_3      D_41       B_3  D_42  \
# 0  0.001734  0.008728  1.006836  0.009224  0.124023  0.008774  0.004707   NaN
# 1  0.005775  0.004925  1.000977  0.006153  0.126709  0.000798  0.002714   NaN
# 2  0.091492  0.021652  1.009766  0.006817  0.123962  0.007599  0.009422   NaN
# 3  0.002455  0.013687  1.002930  0.001372  0.117188  0.000685  0.005531   NaN
# 4  0.002483  0.015190  1.000977  0.007607  0.117310  0.004654  0.009308   NaN
#
# ...

# %%
temp1 = df[df['customer_ID']==df['customer_ID'][0]]

# %%
temp1
# Out:
#                                           customer_ID        S_2       P_2  \
# 0   0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f... 2017-03-09  0.938477
# 1   0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f... 2017-04-07  0.936523
# 2   0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f... 2017-05-28  0.954102
# 3   0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f... 2017-06-13  0.960449
# 4   0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f... 2017-07-16  0.947266
# 5   0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f... 2017-08-04  0.945801
# 6   0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f... 2017-09-18  0.940918
# 7   0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f... 2017-10-08  0.914551
# 8   0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f... 2017-11-20  0.950684
# 9   0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f... 2017-12-04  0.868652
# 10  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f... 2018-01-11  0.909668
# ...

# %%
temp1['P_2'].plot()
# Out:
# <Axes: >

# %%
temp1['D_39'].plot()
# Out:
# <Axes: >

# %%
df.customer_ID.value_counts()[-1]
# Out:
# /var/folders/ry/5l37ld9j319_17ytxrp8r3r00000gn/T/ipykernel_82994/1489580349.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.customer_ID.value_counts()[-1]
# 1

# %%
df.tail()
# Out:
#                                                customer_ID        S_2  \
# 5531446  fffff1d38b785cef84adeace64f8f83db3a0c31e8d92ea... 2017-11-05
# 5531447  fffff1d38b785cef84adeace64f8f83db3a0c31e8d92ea... 2017-12-23
# 5531448  fffff1d38b785cef84adeace64f8f83db3a0c31e8d92ea... 2018-01-06
# 5531449  fffff1d38b785cef84adeace64f8f83db3a0c31e8d92ea... 2018-02-06
# 5531450  fffff1d38b785cef84adeace64f8f83db3a0c31e8d92ea... 2018-03-14
#
#               P_2      D_39       B_1       B_2       R_1       S_3      D_41  \
# 5531446  0.979492  0.416016  0.020813  0.828125  0.003487  0.090759  0.005341
# 5531447  0.984863  0.296631  0.007210  0.812500  0.005905  0.079895  0.002243
# 5531448  0.982910  0.444092  0.013153  0.815430  0.003456  0.100525  0.002111
# 5531449  0.969727  0.442627  0.009857  1.003906  0.005116  0.101807  0.009933
# 5531450  0.981934  0.002474  0.000077  0.992676  0.000809  0.119141  0.003286
#
# ...

# %%
df_label = pd.read_csv("train_labels.csv")
print(df_label.shape)
df_label.head()
# Out:
# (458913, 2)
#                                          customer_ID  target
# 0  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...       0
# 1  00000fd6641609c6ece5454664794f0340ad84dddce9a2...       0
# 2  00001b22f846c82c51f6e3958ccd81970162bae8b007e8...       0
# 3  000041bdba6ecadd89a52d11886e8eaaec9325906c9723...       0
# 4  00007889e4fcd2614b6cbe7f8f3d2e5c728eca32d9eb8a...       0

# %%
df = df.merge(df_label, on = "customer_ID")
print(df.shape)
# Out:
# (5531451, 192)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5531451 entries, 0 to 5531450
# Columns: 192 entries, customer_ID to target_y
# dtypes: category(11), datetime64[ns](1), float16(177), int64(2), object(1)
# memory usage: 2.0+ GB

# %%
df.describe()
# Out:
# /Users/lezhang/Documents/onecareer/onecareer-venv/lib/python3.9/site-packages/pandas/core/nanops.py:1487: RuntimeWarning: overflow encountered in cast
#   return dtype.type(n)
# /Users/lezhang/Documents/onecareer/onecareer-venv/lib/python3.9/site-packages/numpy/core/_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /Users/lezhang/Documents/onecareer/onecareer-venv/lib/python3.9/site-packages/pandas/core/nanops.py:731: RuntimeWarning: invalid value encountered in scalar divide
#   the_mean = the_sum / count if count > 0 else np.nan
# /Users/lezhang/Documents/onecareer/onecareer-venv/lib/python3.9/site-packages/pandas/core/nanops.py:1487: RuntimeWarning: overflow encountered in cast
#   return dtype.type(n)
# /Users/lezhang/Documents/onecareer/onecareer-venv/lib/python3.9/site-packages/numpy/core/_methods.py:49: RuntimeWarning: overflow encountered in reduce
# ...

# %%
d_feats = [name for name in df.columns if name.startswith("D")]
d_feats
# Out:
# ['D_39',
#  'D_41',
#  'D_42',
#  'D_43',
#  'D_44',
#  'D_45',
#  'D_46',
#  'D_47',
#  'D_48',
#  'D_49',
#  'D_50',
#  'D_51',
#  'D_52',
#  'D_53',
#  'D_54',
#  'D_55',
#  'D_56',
#  'D_58',
#  'D_59',
#  'D_60',
#  'D_61',
#  'D_62',
#  'D_63',
#  'D_64',
#  'D_65',
#  'D_66',
#  'D_68',
#  'D_69',
#  'D_70',
#  'D_71',
#  'D_72',
#  'D_73',
#  'D_74',
#  'D_75',
#  'D_76',
#  'D_77',
#  'D_78',
#  'D_79',
#  'D_80',
#  'D_81',
#  'D_82',
#  'D_83',
#  'D_84',
#  'D_86',
#  'D_87',
#  'D_88',
#  'D_89',
#  'D_91',
#  'D_92',
#  'D_93',
#  'D_94',
#  'D_96',
#  'D_102',
#  'D_103',
#  'D_104',
#  'D_105',
#  'D_106',
#  'D_107',
#  'D_108',
#  'D_109',
#  'D_110',
#  'D_111',
#  'D_112',
#  'D_113',
#  'D_114',
#  'D_115',
#  'D_116',
#  'D_117',
#  'D_118',
#  'D_119',
#  'D_120',
#  'D_121',
#  'D_122',
#  'D_123',
#  'D_124',
#  'D_125',
#  'D_126',
#  'D_127',
#  'D_128',
#  'D_129',
#  'D_130',
#  'D_131',
#  'D_132',
#  'D_133',
#  'D_134',
#  'D_135',
#  'D_136',
# ...

# %%
s_feats = [name for name in df.columns if name.startswith("S")]
s_feats
# Out:
# ['S_2',
#  'S_3',
#  'S_5',
#  'S_6',
#  'S_7',
#  'S_8',
#  'S_9',
#  'S_11',
#  'S_12',
#  'S_13',
#  'S_15',
#  'S_16',
#  'S_17',
#  'S_18',
#  'S_19',
#  'S_20',
#  'S_22',
#  'S_23',
#  'S_24',
#  'S_25',
#  'S_26',
#  'S_27']

# %%
p_feats = [name for name in df.columns if name.startswith("P")]
p_feats
# Out:
# ['P_2', 'P_3', 'P_4']

# %%
b_feats = [name for name in df.columns if name.startswith("B")]
b_feats
# Out:
# ['B_1',
#  'B_2',
#  'B_3',
#  'B_4',
#  'B_5',
#  'B_6',
#  'B_7',
#  'B_8',
#  'B_9',
#  'B_10',
#  'B_11',
#  'B_12',
#  'B_13',
#  'B_14',
#  'B_15',
#  'B_16',
#  'B_17',
#  'B_18',
#  'B_19',
#  'B_20',
#  'B_21',
#  'B_22',
#  'B_23',
#  'B_24',
#  'B_25',
#  'B_26',
#  'B_27',
#  'B_28',
#  'B_29',
#  'B_30',
#  'B_31',
#  'B_32',
#  'B_33',
#  'B_36',
#  'B_37',
#  'B_38',
#  'B_39',
#  'B_40',
#  'B_41',
#  'B_42']

# %%
r_feats = [name for name in df.columns if name.startswith("R")]
r_feats
# Out:
# ['R_1',
#  'R_2',
#  'R_3',
#  'R_4',
#  'R_5',
#  'R_6',
#  'R_7',
#  'R_8',
#  'R_9',
#  'R_10',
#  'R_11',
#  'R_12',
#  'R_13',
#  'R_14',
#  'R_15',
#  'R_16',
#  'R_17',
#  'R_18',
#  'R_19',
#  'R_20',
#  'R_21',
#  'R_22',
#  'R_23',
#  'R_24',
#  'R_25',
#  'R_26',
#  'R_27',
#  'R_28']

# %%
df.customer_ID.value_counts()
# Out:
# customer_ID
# 0000099d6bd597052cdcda90ffabf56573fe9d7c79be5fbac11a8ed792feb62a    13
# a3111280bfa1ed8fafd0b06839eb707f4538497e8087cb62958bb03e1bdde214    13
# a31376930229162f886c091e5a56a528f81c10a523285828ed05a6e9ccf56722    13
# a312c595dfaee96c8a597107d2754a49b1acfd127400d98991762d87837b1b65    13
# a312aff722e7230f9d6a313ff777d6f00166c6bada21a333982426758a2e2a9d    13
#                                                                     ..
# a84839802f1f37a86a7fe34ddba4791d33d878df3937b509841def0a9e252748     1
# 01f4f7b14d83b6a8f88e4355279224615da083b19e3e5f15b98f274ced8cf752     1
# eef07ea56302cebcd57374c6565bb3e5c7af856796d9cbc31ed42aa0fc73b7fc     1
# d192480082e86e3b4da68f014b284f2a2624b45956eed279416c796de043b7ce     1
# d9ea3cffff889b522a69bde89aee382dcff8bffe32c9a38653bdaa2ff4330041     1
# Name: count, Length: 458913, dtype: int64

# %%
plt.plot(df.customer_ID.value_counts())
# Out:
# Error in callback <function _draw_all_if_interactive at 0x11dd29ca0> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/Documents/onecareer/onecareer-venv/lib/python3.9/site-packages/matplotlib/pyplot.py:197, in _draw_all_if_interactive()
#     195 def _draw_all_if_interactive() -> None:
#     196     if matplotlib.is_interactive():
# --> 197         draw_all()
#
# File ~/Documents/onecareer/onecareer-venv/lib/python3.9/site-packages/matplotlib/_pylab_helpers.py:132, in Gcf.draw_all(cls, force)
#     130 for manager in cls.get_all_fig_managers():
#     131     if force or manager.canvas.figure.stale:
# --> 132         manager.canvas.draw_idle()
#
# File ~/Documents/onecareer/onecareer-venv/lib/python3.9/site-packages/matplotlib/backend_bases.py:1893, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
# ...

# %%
df_label.target.value_counts()
# Out:
# target
# 0    340085
# 1    118828
# Name: count, dtype: int64

# %%
df_d39 = df[['customer_ID', 'S_2', 'D_39']]
df_d39.head()
# Out:
#                                          customer_ID        S_2      D_39
# 0  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f... 2017-03-09  0.001734
# 1  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f... 2017-04-07  0.005775
# 2  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f... 2017-05-28  0.091492
# 3  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f... 2017-06-13  0.002455
# 4  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f... 2017-07-16  0.002483

# %%
df_s3 = df[['customer_ID', 'S_2', 'S_3']]
df_s3.head()
# Out:
#                                          customer_ID        S_2       S_3
# 0  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f... 2017-03-09  0.124023
# 1  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f... 2017-04-07  0.126709
# 2  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f... 2017-05-28  0.123962
# 3  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f... 2017-06-13  0.117188
# 4  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f... 2017-07-16  0.117310

# %%
df_b30 = df[['customer_ID', 'S_2', 'B_30']]
df_b30.head()
# Out:
#                                          customer_ID        S_2 B_30
# 0  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f... 2017-03-09  0.0
# 1  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f... 2017-04-07  0.0
# 2  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f... 2017-05-28  0.0
# 3  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f... 2017-06-13  0.0
# 4  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f... 2017-07-16  0.0

# %%
df_b30.B_30.value_counts()
# Out:
# B_30
# 0.0    4710663
# 1.0     763955
# 2.0      54817
# Name: count, dtype: int64
